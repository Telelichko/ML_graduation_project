# %%
import pandas as pd
import numpy as np

import sys

# %%
# Подготовка данных

# Чтение данных с наименованиями полей
data_column_names = pd.read_excel('../input_data/data_from_site3.xlsx', sheet_name='names')

# Удаление событий сс пустыми значениями в поле checked_parameter
data_column_names['checked_parameter'].replace('', np.nan, inplace=True)
data_column_names.dropna(subset=['checked_parameter'], inplace=True)

# Получение списка исследуемых параметров
list_data_necessary=[]
for n_data in data_column_names['N']:
    list_data_necessary.append(n_data)
    
# Получение всех данных теста
data_all = pd.read_excel('../input_data/data_from_site2.xlsx', sheet_name='data')

# Получение данных по иследуемым параметрам
data_necessary=data_all[list_data_necessary]
data_necessary.head()

# Переименование заголовков столбцов
old_names = list_data_necessary
new_names = data_necessary.loc[0]
data_necessary.rename(columns=dict(zip(old_names, new_names)), inplace=True) 
data_necessary.drop([0], inplace=True)

# !!! Предварительно нужно провести нормализацию столбцов

# Объединение столбцов с пенсией и зарплатой
data_necessary.loc[data_necessary['Средняя_зарплата_месяц']=='     .  ', 'Средняя_зарплата_месяц']=data_necessary['Сумма_пенсии']
data_necessary.rename(columns=dict(zip(['Средняя_зарплата_месяц'], ['Размер_зарплаты_пенсии'])), inplace=True) 
del data_necessary['Сумма_пенсии']   



# data_necessary.replace('.', '0', inplace=True)
# for line_data in data_all:
#     if data_necessary['Средняя_зарплата_месяц'][line_data] == '.':
#         data_necessary.loc['Средняя_зарплата_месяц'][line_data] = data_necessary['Сумма_пенсии'][line_data]
data_necessary.head()

# %%
data_necessary.to_excel('../output_data/data_to_experiments.xlsx', sheet_name='data')

# %%
# Получение первых 5 значений
data_column_names.head()
# Out:
#        N                field_name checked_parameter  \
# 13    14   Степень_состоятельности               286
# 14    15            Степень_власти               286
# 15    16  Степень_уважения_другими               286
# 18    19              Состав_семьи               286
# 165  166             Наличие_детей               286
#
#                                            explanation
# 13    Насколько объективно оценивается состоятельность
# 14                           Влияние ощущения на доход
# 15                           Влияние ощущения на доход
# 18   Влияние количества членов семьи на необходимос...
# 165        Влияет на необходимость больше зарабатывать

# %%
# Получение значений выбранных полей
data_column_names
# Out:
#        N                   field_name checked_parameter  \
# 13    14      Степень_состоятельности               286
# 14    15               Степень_власти               286
# 15    16     Степень_уважения_другими               286
# 18    19                 Состав_семьи               286
# 165  166                Наличие_детей               286
# 254  255          Уровень_образования               286
# 268  269             Наемный_работник               286
# 269  270         Владелец_предприятия               286
# 270  271                           ИП               286
# 271  272                       Фермер               286
# 272  273           Свободный_работник               286
# 276  277          Профессия_должность               286
# 277  278        Деятельность_компании               286
# 285  286       Средняя_зарплата_месяц                 +
# 289  290                 Сумма_пенсии                 +
# 344  345                     Верующий               286
# 348  349       Пользование_интернетом               286
# 358  359              Мессенджеры_нет               286
# 367  368           Проживание_область               286
# 369  370  Проживание_населенный_пункт               286
#
#                                            explanation
# 13    Насколько объективно оценивается состоятельность
# 14                           Влияние ощущения на доход
# 15                           Влияние ощущения на доход
# 18   Влияние количества членов семьи на необходимос...
# 165        Влияет на необходимость больше зарабатывать
# 254                       Влияние образования на доход
# 268                                                NaN
# 269                                                NaN
# 270                                                NaN
# 271                                                NaN
# 272                                                NaN
# 276                                                NaN
# 277                                                NaN
# 285                                                NaN
# 289                                                NaN
# 344  Гипотеза: наличие веры может снизить тревожнос...
# 348  Взаимосвязь использования интернета и уровнем ...
# 358  Поиск обратной зависимости от неприменения мес...
# 367                          Влияние дохода от области
# 369          Влияние дохода от типа населенного пункта

# %%
# Получение значений с индексами иследуемых параметров
data_column_names['N']
# Out:
# 13      14
# 14      15
# 15      16
# 18      19
# 165    166
# 254    255
# 268    269
# 269    270
# 270    271
# 271    272
# 272    273
# 276    277
# 277    278
# 285    286
# 289    290
# 344    345
# 348    349
# 358    359
# 367    368
# 369    370
# Name: N, dtype: int64

# %%
    
print(list_data_necessary)
# Out:
# [14, 15, 16, 19, 166, 255, 269, 270, 271, 272, 273, 277, 278, 286, 290, 345, 349, 359, 368, 370]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adb5ec132f67> in <module>
#       1 # Получение данных по иследуемым параметрам
# ----> 2 data_necessary=data_all[list_data_necessary]
#       3 data_necessary.head()
#
# NameError: name 'data_all' is not defined

# %%
data_necessary.head()
# Out:
# C:\Users\Tasha\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# C:\Users\Tasha\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Степень_состоятельности Степень_власти Степень_уважения_другими  \
# 1                       6              3                        5
# 2                       4              3                        6
# 3                       4              6                        6
# 4                       2              2                        3
# 5                       1             99                        9
#
#   Состав_семьи Наличие_детей Уровень_образования Наемный_работник  \
# 1            5             1                   3                1
# 2            1             1                   1                .
# 3            3             2                   3                1
# 4            4             1                   3                .
# 5            1             1                   1                .
#
#   Владелец_предприятия        ИП    Фермер Свободный_работник  \
# 1                    0         0         0                  0
# 2                    .         .         .                  .
# 3                    0         0         0                  0
# 4                    .         .         .                  .
# 5                    .         .         .                  .
#
#                                  Профессия_должность  \
# 1  бухгалтер                                     ...
# 2                                                ...
# 3  санитарка                                     ...
# 4                                                ...
# 5                                                ...
#
#                                Деятельность_компании Средняя_зарплата_месяц  \
# 1  пекарня                                       ...                  25000
# 2                                                ...                    .
# 3  Медицина                                      ...                  15000
# 4                                                ...                    .
# 5                                                ...                    .
#
#   Сумма_пенсии Верующий Пользование_интернетом Мессенджеры_нет  \
# 1          .          1                      3               1
# 2         7000        1                      1               .
# 3          .          1                      3               0
# 4          .          1                      2               1
# 5        10178        1                      1               .
#
#   Проживание_область Проживание_населенный_пункт
# 1                 24                           1
# 2                 70                           2
# 3                 19                           1
# 4                  4                           2
# 5                 92                           1

# %%
 
data_necessary.head()
# Out:
# C:\Users\Tasha\anaconda3\lib\site-packages\pandas\core\indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\Tasha\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Tasha\anaconda3\lib\site-packages\pandas\core\frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#   Степень_состоятельности Степень_власти Степень_уважения_другими  \
# 1                       6              3                        5
# 2                       4              3                        6
# 3                       4              6                        6
# 4                       2              2                        3
# 5                       1             99                        9
#
#   Состав_семьи Наличие_детей Уровень_образования Наемный_работник  \
# 1            5             1                   3                1
# 2            1             1                   1                .
# 3            3             2                   3                1
# 4            4             1                   3                .
# 5            1             1                   1                .
#
#   Владелец_предприятия        ИП    Фермер Свободный_работник  \
# 1                    0         0         0                  0
# 2                    .         .         .                  .
# 3                    0         0         0                  0
# 4                    .         .         .                  .
# 5                    .         .         .                  .
#
#                                  Профессия_должность  \
# 1  бухгалтер                                     ...
# 2                                                ...
# 3  санитарка                                     ...
# 4                                                ...
# 5                                                ...
#
#                                Деятельность_компании Размер_зарплаты_пенсии  \
# 1  пекарня                                       ...                  25000
# 2                                                ...                   7000
# 3  Медицина                                      ...                  15000
# 4                                                ...                    .
# 5                                                ...                  10178
#
#   Сумма_пенсии Верующий Пользование_интернетом Мессенджеры_нет  \
# 1          .          1                      3               1
# 2         7000        1                      1               .
# 3          .          1                      3               0
# 4          .          1                      2               1
# 5        10178        1                      1               .
#
#   Проживание_область Проживание_населенный_пункт
# 1                 24                           1
# 2                 70                           2
# 3                 19                           1
# 4                  4                           2
# 5                 92                           1

# %%
# data_necessary['Средняя_зарплата_месяц'].fillna(data_necessary['Сумма_пенсии'])
# Прежде чем дополнять значения полей з/п с полями пенсии
# data_column_names['Средняя_зарплата_месяц'].replace('', 2, inplace=True)
# data_column_names['Средняя_зарплата_месяц']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Средняя_зарплата_месяц'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-182-5c4d1a27281d> in <module>
#       4 # data_column_names['Средняя_зарплата_месяц']
#       5
# ----> 6 data_necessary.loc['Средняя_зарплата_месяц'].replace('.', '0', inplace=True)
#       7
#       8
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1962         # fall thru to straight lookup
#    1963         self._validate_key(key, axis)
# -> 1964         return self._get_label(key, axis=axis)
#    1965
#    1966
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     622             raise IndexingError("no slices here, handle elsewhere")
#     623
# --> 624         return self.obj._xs(label, axis=axis)
#     625
#     626     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Средняя_зарплата_месяц'

# %%
data_necessary.head()
# Out:
#                        14              15                        16   \
# 0  Степень_состоятельности  Степень_власти  Степень_уважения_другими
# 1                        6               3                         5
# 2                        4               3                         6
# 3                        4               6                         6
# 4                        2               2                         3
#
#             19             166                  255               269  \
# 0  Состав_семьи  Наличие_детей  Уровень_образования  Наемный_работник
# 1             5              1                    3                 1
# 2             1              1                    1                 .
# 3             3              2                    3                 1
# 4             4              1                    3                 .
#
#                     270       271       272                 273  \
# 0  Владелец_предприятия        ИП    Фермер  Свободный_работник
# 1                     0         0         0                   0
# 2                     .         .         .                   .
# 3                     0         0         0                   0
# 4                     .         .         .                   .
#
#                                                  277  \
# 0                                Профессия_должность
# 1  бухгалтер                                     ...
# 2                                                ...
# 3  санитарка                                     ...
# 4                                                ...
#
#                                                  278                     286  \
# 0                              Деятельность_компании  Средняя_зарплата_месяц
# 1  пекарня                                       ...                   25000
# 2                                                ...                     .
# 3  Медицина                                      ...                   15000
# 4                                                ...                     .
#
#             290       345                     349              359  \
# 0  Сумма_пенсии  Верующий  Пользование_интернетом  Мессенджеры_нет
# 1           .           1                       3                1
# 2          7000         1                       1                .
# 3           .           1                       3                0
# 4           .           1                       2                1
#
#                   368                          370
# 0  Проживание_область  Проживание_населенный_пункт
# 1                  24                            1
# 2                  70                            2
# 3                  19                            1
# 4                   4                            2
